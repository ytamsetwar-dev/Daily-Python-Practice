# %% [markdown]
# # Intro to function()

# %%
# Basic Example 1

def sum(a,b):
    add=a+b
    return add
sum(10,20)
# Out:
# 0

# %%
# 
To print String .. 
def welcome():
    print("Hello good morning")  
welcome()
# Out:
# Hello good morning

# %% [markdown]
# ### 1. Zero-Parameter Functions

# %%
def seperator():
    print("="*30)
seperator()

# %% [markdown]
# ### 2. Default Parameters

# %%
def sum(a=0,b=0):    # By using Default parameter
    add=a+b
    return add
sum()
# Out:
# 0
