# %%
list1= ["Yash","Nayan","Punit"]
list1.append(["Paritosh"])
list1.append(["Ram"])
list1.extend(["Rohan"])
list1.extend(["Rahul","Shau"])
list1
# Out:
# ['Yash', 'Nayan', 'Punit', ['Paritosh'], ['Ram'], 'Rohan', 'Rahul', 'Shau']

# %%
name="yash"
age=20
print("My name is ",name," and age is",age)
# Out:
# My name is  yash  and age is 20

# %%
A=10

Result = 1*(A%2==0) or 0

#Result
"Even" *Result or "Odd"
# Out:
# 'Even'
